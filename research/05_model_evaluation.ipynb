# %%
import os

# %%
# %pwd
# Out:
# 'c:\\Users\\Salih\\Desktop\\Text-Summarizer-Project\\research'

# %%
os.chdir("../")

# %%
# %pwd
# Out:
# 'c:\\Users\\Salih\\Desktop\\Text-Summarizer-Project'

# %%
from dataclasses import dataclass
from pathlib import Path

@dataclass(frozen=True)
class ModelEvaluationConfig:
    root_dir: Path
    data_path: Path
    model_path: Path
    tokenizer_path: Path
    metric_file_name: Path

# %%
from textSummarizer.constants import *
from textSummarizer.utils.common import read_yaml, create_directories

# %%
class ConfigurationManager:
    def __init__(
            self, 
            config_filepath=CONFIG_FILE_PATH, 
            params_filepath=PARAMS_FILE_PATH):
        self.config = read_yaml(config_filepath)
        self.params = read_yaml(params_filepath)
        
        create_directories([self.config.artifacts_root])
    
    def get_model_evaluation_config(self) -> ModelEvaluationConfig:
        config = self.config.model_evaluation

        create_directories([config.root_dir])

        model_evaluation_config = ModelEvaluationConfig(
            root_dir=config.root_dir,
            data_path=config.data_path,
            model_path=config.model_path,
            tokenizer_path=config.tokenizer_path,
            metric_file_name=config.metric_file_name
        )

        return model_evaluation_config

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
from datasets import load_dataset, load_from_disk
import evaluate
import torch
import pandas as pd
from tqdm import tqdm

# %%
class ModelEvaluation:
    def __init__(self, config: ModelEvaluationConfig):
        self.config = config
        
    def generate_batch_sized_chunks(self,list_of_elements, batch_size):
        """split the dataset into smaller batches that we can process simultaneously
        Yield successive batch-sized chunks from list_of_elements."""
        for i in range(0, len(list_of_elements), batch_size):
            yield list_of_elements[i : i + batch_size]

    
    def calculate_metric_on_test_ds(self,dataset, metric, model, tokenizer, 
                               batch_size=16, device="cuda" if torch.cuda.is_available() else "cpu", 
                               column_text="article", 
                               column_summary="highlights"):
        article_batches = list(self.generate_batch_sized_chunks(dataset[column_text], batch_size))
        target_batches = list(self.generate_batch_sized_chunks(dataset[column_summary], batch_size))

        for article_batch, target_batch in tqdm(
            zip(article_batches, target_batches), total=len(article_batches)):
            
            inputs = tokenizer(article_batch, max_length=1024,  truncation=True, 
                            padding="max_length", return_tensors="pt")
            
            summaries = model.generate(input_ids=inputs["input_ids"].to(device),
                            attention_mask=inputs["attention_mask"].to(device), 
                            length_penalty=0.8, num_beams=8, max_length=128)
            ''' parameter for length penalty ensures that the model does not generate sequences that are too long. '''
            
            # Finally, we decode the generated texts, 
            # replace the  token, and add the decoded texts with the references to the metric.
            decoded_summaries = [tokenizer.decode(s, skip_special_tokens=True, 
                                    clean_up_tokenization_spaces=True) 
                for s in summaries]      
            
            decoded_summaries = [d.replace("", " ") for d in decoded_summaries]
            
            
            metric.add_batch(predictions=decoded_summaries, references=target_batch)
            
        #  Finally compute and return the ROUGE scores.
        score = metric.compute()
        return score


    def evaluate(self):
        device = "cuda" if torch.cuda.is_available() else "cpu"
        tokenizer = AutoTokenizer.from_pretrained(self.config.tokenizer_path)
        model_pegasus = AutoModelForSeq2SeqLM.from_pretrained(self.config.model_path).to(device)
       
        #loading data 
        dataset_samsum_pt = load_from_disk(self.config.data_path)


        rouge_names = ["rouge1", "rouge2", "rougeL", "rougeLsum"]
  
        rouge_metric = evaluate.load('rouge')

        score = self.calculate_metric_on_test_ds(
        dataset_samsum_pt['test'][0:10], rouge_metric, model_pegasus, tokenizer, batch_size = 2, column_text = 'dialogue', column_summary= 'summary'
            )

        rouge_dict = dict((rn, score[rn].mid.fmeasure ) for rn in rouge_names )

        df = pd.DataFrame(rouge_dict, index = ['pegasus'] )
        df.to_csv(self.config.metric_file_name, index=False)

# %%
try:
    config = ConfigurationManager()
    model_evaluation_config = config.get_model_evaluation_config()
    model_evaluation_config = ModelEvaluation(config=model_evaluation_config)
    model_evaluation_config.evaluate()
except Exception as e:
    raise e
# Out:
# [2026-05-22 16:15:51,597: INFO: common: yaml file: config\config.yaml loaded successfully]
# [2026-05-22 16:15:51,616: INFO: common: yaml file: params.yaml loaded successfully]
# [2026-05-22 16:15:51,623: INFO: common: created directory at: artifacts]
# [2026-05-22 16:15:51,624: INFO: common: created directory at: artifacts/model_evaluation]
# ---------------------------------------------------------------------------
# HFValidationError                         Traceback (most recent call last)
# File c:\Users\Salih\Desktop\Text-Summarizer-Project\.venv\lib\site-packages\transformers\utils\hub.py:422, in cached_files(path_or_repo_id, filenames, cache_dir, force_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, tqdm_class, **deprecated_kwargs)
#     420 if len(full_filenames) == 1:
#     421     # This is slightly better for only 1 file
# --> 422     hf_hub_download(
#     423         path_or_repo_id,
#     424         filenames[0],
#     425         subfolder=None if len(subfolder) == 0 else subfolder,
#     426         repo_type=repo_type,
#     427         revision=revision,
#     428         cache_dir=cache_dir,
#     429         user_agent=user_agent,
#     430         force_download=force_download,
#     431         proxies=proxies,
#     432         token=token,
#     433         local_files_only=local_files_only,
#     434         tqdm_class=tqdm_class,
#     435     )
#     436 else:
#
# File c:\Users\Salih\Desktop\Text-Summarizer-Project\.venv\lib\site-packages\huggingface_hub\utils\_validators.py:84, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#      83     if arg_name in ["repo_id", "from_id", "to_id"]:
# ---> 84         validate_repo_id(arg_value)
#      86 kwargs = smoothly_deprecate_legacy_arguments(fn_name=fn.__name__, kwargs=kwargs)
#
# File c:\Users\Salih\Desktop\Text-Summarizer-Project\.venv\lib\site-packages\huggingface_hub\utils\_validators.py:132, in validate_repo_id(repo_id)
#     131 if repo_id.count("/") > 1:
# --> 132     raise HFValidationError(
#     133         "Repo id must be in the form 'repo_name' or 'namespace/repo_name':"
#     134         f" '{repo_id}'. Use `repo_type` argument if needed."
#     135     )
#     137 if not REPO_ID_REGEX.match(repo_id):
#
# HFValidationError: Repo id must be in the form 'repo_name' or 'namespace/repo_name': 'artifacts/model_trainer/tokenizer'. Use `repo_type` argument if needed.
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# File c:\Users\Salih\Desktop\Text-Summarizer-Project\.venv\lib\site-packages\transformers\models\auto\tokenization_auto.py:694, in AutoTokenizer.from_pretrained(cls, pretrained_model_name_or_path, *inputs, **kwargs)
#     693 try:
# --> 694     config = AutoConfig.from_pretrained(
#     695         pretrained_model_name_or_path, trust_remote_code=trust_remote_code, **kwargs
#     696     )
#     697 except (ValueError, OSError):
#
# File c:\Users\Salih\Desktop\Text-Summarizer-Project\.venv\lib\site-packages\transformers\models\auto\configuration_auto.py:374, in AutoConfig.from_pretrained(cls, pretrained_model_name_or_path, **kwargs)
#     372 code_revision = kwargs.pop("code_revision", None)
# --> 374 config_dict, unused_kwargs = PreTrainedConfig.get_config_dict(pretrained_model_name_or_path, **kwargs)
#     375 has_remote_code = "auto_map" in config_dict and "AutoConfig" in config_dict["auto_map"]
#
# File c:\Users\Salih\Desktop\Text-Summarizer-Project\.venv\lib\site-packages\transformers\configuration_utils.py:683, in PreTrainedConfig.get_config_dict(cls, pretrained_model_name_or_path, **kwargs)
#     682 # Get config dict associated with the base config file
# --> 683 config_dict, kwargs = cls._get_config_dict(pretrained_model_name_or_path, **kwargs)
#     684 if config_dict is None:
#
# File c:\Users\Salih\Desktop\Text-Summarizer-Project\.venv\lib\site-packages\transformers\configuration_utils.py:738, in PreTrainedConfig._get_config_dict(cls, pretrained_model_name_or_path, **kwargs)
#     736 try:
#     737     # Load from local folder or from cache or download from model Hub and cache
# --> 738     resolved_config_file = cached_file(
#     739         pretrained_model_name_or_path,
#     740         configuration_file,
#     741         cache_dir=cache_dir,
#     742         force_download=force_download,
#     743         proxies=proxies,
#     744         local_files_only=local_files_only,
#     745         token=token,
#     746         user_agent=user_agent,
#     747         revision=revision,
#     748         subfolder=subfolder,
#     749         _commit_hash=commit_hash,
#     750     )
#     751     if resolved_config_file is None:
#
# File c:\Users\Salih\Desktop\Text-Summarizer-Project\.venv\lib\site-packages\transformers\utils\hub.py:278, in cached_file(path_or_repo_id, filename, **kwargs)
#     228 """
#     229 Tries to locate a file in a local folder and repo, downloads and cache it if necessary.
#     230
#    (...)
#     276 ```
#     277 """
# --> 278 file = cached_files(path_or_repo_id=path_or_repo_id, filenames=[filename], **kwargs)
#     279 file = file[0] if file is not None else file
#
# File c:\Users\Salih\Desktop\Text-Summarizer-Project\.venv\lib\site-packages\transformers\utils\hub.py:473, in cached_files(path_or_repo_id, filenames, cache_dir, force_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, tqdm_class, **deprecated_kwargs)
#     472 elif isinstance(e, ValueError):
# --> 473     raise OSError(f"{e}") from e
#     475 # Now we try to recover if we can find all files correctly in the cache
#
# OSError: Repo id must be in the form 'repo_name' or 'namespace/repo_name': 'artifacts/model_trainer/tokenizer'. Use `repo_type` argument if needed.
#
# During handling of the above exception, another exception occurred:
#
# HFValidationError                         Traceback (most recent call last)
# File c:\Users\Salih\Desktop\Text-Summarizer-Project\.venv\lib\site-packages\transformers\utils\hub.py:422, in cached_files(path_or_repo_id, filenames, cache_dir, force_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, tqdm_class, **deprecated_kwargs)
#     420 if len(full_filenames) == 1:
#     421     # This is slightly better for only 1 file
# --> 422     hf_hub_download(
#     423         path_or_repo_id,
#     424         filenames[0],
#     425         subfolder=None if len(subfolder) == 0 else subfolder,
#     426         repo_type=repo_type,
#     427         revision=revision,
#     428         cache_dir=cache_dir,
#     429         user_agent=user_agent,
#     430         force_download=force_download,
#     431         proxies=proxies,
#     432         token=token,
#     433         local_files_only=local_files_only,
#     434         tqdm_class=tqdm_class,
#     435     )
#     436 else:
#
# File c:\Users\Salih\Desktop\Text-Summarizer-Project\.venv\lib\site-packages\huggingface_hub\utils\_validators.py:84, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#      83     if arg_name in ["repo_id", "from_id", "to_id"]:
# ---> 84         validate_repo_id(arg_value)
#      86 kwargs = smoothly_deprecate_legacy_arguments(fn_name=fn.__name__, kwargs=kwargs)
#
# File c:\Users\Salih\Desktop\Text-Summarizer-Project\.venv\lib\site-packages\huggingface_hub\utils\_validators.py:132, in validate_repo_id(repo_id)
#     131 if repo_id.count("/") > 1:
# --> 132     raise HFValidationError(
#     133         "Repo id must be in the form 'repo_name' or 'namespace/repo_name':"
#     134         f" '{repo_id}'. Use `repo_type` argument if needed."
#     135     )
#     137 if not REPO_ID_REGEX.match(repo_id):
#
# HFValidationError: Repo id must be in the form 'repo_name' or 'namespace/repo_name': 'artifacts/model_trainer/tokenizer'. Use `repo_type` argument if needed.
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# Cell In[15], line 7
#       5     model_evaluation_config.evaluate()
#       6 except Exception as e:
# ----> 7     raise e
#
# Cell In[15], line 5
#       3     model_evaluation_config = config.get_model_evaluation_config()
#       4     model_evaluation_config = ModelEvaluation(config=model_evaluation_config)
# ----> 5     model_evaluation_config.evaluate()
#       6 except Exception as e:
#       7     raise e
#
# Cell In[14], line 48, in ModelEvaluation.evaluate(self)
#      46 def evaluate(self):
#      47     device = "cuda" if torch.cuda.is_available() else "cpu"
# ---> 48     tokenizer = AutoTokenizer.from_pretrained(self.config.tokenizer_path)
#      49     model_pegasus = AutoModelForSeq2SeqLM.from_pretrained(self.config.model_path).to(device)
#      51     #loading data
#
# File c:\Users\Salih\Desktop\Text-Summarizer-Project\.venv\lib\site-packages\transformers\models\auto\tokenization_auto.py:698, in AutoTokenizer.from_pretrained(cls, pretrained_model_name_or_path, *inputs, **kwargs)
#     694         config = AutoConfig.from_pretrained(
#     695             pretrained_model_name_or_path, trust_remote_code=trust_remote_code, **kwargs
#     696         )
#     697     except (ValueError, OSError):
# --> 698         config = PreTrainedConfig.from_pretrained(pretrained_model_name_or_path, **kwargs)
#     700 config_model_type = config.model_type
#     702 # Next, let's try to use the tokenizer_config file to get the tokenizer class.
#
# File c:\Users\Salih\Desktop\Text-Summarizer-Project\.venv\lib\site-packages\transformers\configuration_utils.py:642, in PreTrainedConfig.from_pretrained(cls, pretrained_model_name_or_path, cache_dir, force_download, local_files_only, token, revision, **kwargs)
#     639 kwargs["local_files_only"] = local_files_only
#     640 kwargs["revision"] = revision
# --> 642 config_dict, kwargs = cls.get_config_dict(pretrained_model_name_or_path, **kwargs)
#     643 if cls.base_config_key and cls.base_config_key in config_dict:
#     644     config_dict = config_dict[cls.base_config_key]
#
# File c:\Users\Salih\Desktop\Text-Summarizer-Project\.venv\lib\site-packages\transformers\configuration_utils.py:683, in PreTrainedConfig.get_config_dict(cls, pretrained_model_name_or_path, **kwargs)
#     681 original_kwargs = copy.deepcopy(kwargs)
#     682 # Get config dict associated with the base config file
# --> 683 config_dict, kwargs = cls._get_config_dict(pretrained_model_name_or_path, **kwargs)
#     684 if config_dict is None:
#     685     return {}, kwargs
#
# File c:\Users\Salih\Desktop\Text-Summarizer-Project\.venv\lib\site-packages\transformers\configuration_utils.py:738, in PreTrainedConfig._get_config_dict(cls, pretrained_model_name_or_path, **kwargs)
#     734 configuration_file = kwargs.pop("_configuration_file", CONFIG_NAME) if gguf_file is None else gguf_file
#     736 try:
#     737     # Load from local folder or from cache or download from model Hub and cache
# --> 738     resolved_config_file = cached_file(
#     739         pretrained_model_name_or_path,
#     740         configuration_file,
#     741         cache_dir=cache_dir,
#     742         force_download=force_download,
#     743         proxies=proxies,
#     744         local_files_only=local_files_only,
#     745         token=token,
#     746         user_agent=user_agent,
#     747         revision=revision,
#     748         subfolder=subfolder,
#     749         _commit_hash=commit_hash,
#     750     )
#     751     if resolved_config_file is None:
#     752         return None, kwargs
#
# File c:\Users\Salih\Desktop\Text-Summarizer-Project\.venv\lib\site-packages\transformers\utils\hub.py:278, in cached_file(path_or_repo_id, filename, **kwargs)
#     223 def cached_file(
#     224     path_or_repo_id: str | os.PathLike,
#     225     filename: str,
#     226     **kwargs,
#     227 ) -> str | None:
#     228     """
#     229     Tries to locate a file in a local folder and repo, downloads and cache it if necessary.
#     230
#    (...)
#     276     ```
#     277     """
# --> 278     file = cached_files(path_or_repo_id=path_or_repo_id, filenames=[filename], **kwargs)
#     279     file = file[0] if file is not None else file
#     280     return file
#
# File c:\Users\Salih\Desktop\Text-Summarizer-Project\.venv\lib\site-packages\transformers\utils\hub.py:473, in cached_files(path_or_repo_id, filenames, cache_dir, force_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, tqdm_class, **deprecated_kwargs)
#     467     raise OSError(
#     468         f"PermissionError at {e.filename} when downloading {path_or_repo_id}. "
#     469         "Check cache directory permissions. Common causes: 1) another user is downloading the same model (please wait); "
#     470         "2) a previous download was canceled and the lock file needs manual removal."
#     471     ) from e
#     472 elif isinstance(e, ValueError):
# --> 473     raise OSError(f"{e}") from e
#     475 # Now we try to recover if we can find all files correctly in the cache
#     476 resolved_files = [
#     477     _get_cache_file_to_return(path_or_repo_id, filename, cache_dir, revision, repo_type)
#     478     for filename in full_filenames
#     479 ]
#
# OSError: Repo id must be in the form 'repo_name' or 'namespace/repo_name': 'artifacts/model_trainer/tokenizer'. Use `repo_type` argument if needed.
